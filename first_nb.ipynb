# %% [markdown]
# <a href="https://colab.research.google.com/github/Asrorbek2605/apps/blob/main/first_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("my first code")
# Out:
# my first code

# %%
! ls
# Out:
# sample_data

# %%
import pandas as pd
files = pd.read_excel('./data/filesss.xlsx')
files.head()
# Out:
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2         1.0
# 3         1.0
# 4         1.0
#
#   Sirtqi bo'lim\n II kurs ta'lim talabalari uchun\n1-yarim yillik  Unnamed: 2  \
# 0                                                Kun                 juft-lik
# 1                                                NaN                      NaN
# 2                              Dushanba \n16.10.2023                       IV
# 3                                                NaN                      NaN
# 4                                                NaN                        V
#
#     Unnamed: 3 Unnamed: 4  \
# 0         Soat   Tanaffus
# 1          NaN        NaN
# 2  1320 - 1440         10
# 3          NaN        NaN
# 4  1450 - 1610         10
#
#   M  A  S H  G'  U  L  O  T  L  A  R     J  A  D  V  A  L  I  \
# 0                                              SI-74
# 1                                                 23
# 2  Mikroiqtisodiyot. Makroiqtisodiyot\nUmarov F. 417
# ...
